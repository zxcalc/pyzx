# %% [markdown]
# # Benchmark
#
# This notebook provides a straightforward way to compare the PyZX optimization routines against other approaches on a standard set of benchmark circuits.

# %% [markdown]
# First we execute the standard set of imports:

# %%
import random, math, os, time
import sys; sys.path.append('..')
import pyzx as zx
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# The following class is some boilerplate around the simplification routines so that we can more easily print the relevant metrics

# %%
class CircuitComparer:
    def __init__(self, dirname, before, after):
        self.fname_before = os.path.join(dirname, before)
        if after:
            self.fname_after = os.path.join(dirname, after)
        else:
            self.fname_after = ""
        self.fname_tpar = ""
        if before.find('before') != -1:
            self.name = before[:-7]
        else:
            self.name = before
        self.has_run = False
    def __str__(self):
        return "CircuitComparer({}, {})".format(self.name, str(self.has_run))
    def __repr__(self):
        return str(self)
    
    def run(self):
        if self.has_run: return True
        c = zx.Circuit.load(self.fname_before).to_basic_gates()
        if self.fname_after:
            c_opt = zx.Circuit.load(self.fname_after).to_basic_gates()
            self.t_opt = c_opt.tcount()
        else:
            self.t_opt = '-'
        self.qubits = c.qubits
        if self.fname_tpar:
            c2 = zx.Circuit.load(self.fname_tpar)
            self.tpar = c2.tcount()
        else: self.tpar = "-"
        self.gatecount = len(c.gates)
        self.t_before = c.tcount()
        g = c.to_graph()
        t = time.time()
        g = zx.simplify.teleport_reduce(g)
        self.t_after = zx.tcount(g)
        self.time_simpl = time.time() - t
        t = time.time()
        c_opt = zx.extract.streaming_extract(g).to_basic_gates()
        c_opt = zx.optimize.basic_optimization(c_opt).to_basic_gates()
        self.c_opt = c_opt
        c_id = c.adjoint()
        c_id.add_circuit(c_opt)
        g = c_id.to_graph()
        zx.simplify.full_reduce(g)
        if g.num_vertices() == 2*len(g.inputs):
            self.verified = "Y"
        else: self.verified = "-"
        
        self.extracts = True
        self.time_extr = 0.0
#         try: 
#             c2 = zx.extract.streaming_extract(g,quiet=True)
#             self.time_extr = time.time() - t
#         except Exception:
#             self.extracts = False
#             self.time_extr = -1
        self.has_run = True
        
        return True
    
    def get_output(self):
        if not self.has_run:
            self.run()
        s = self.name.ljust(20) + str(self.qubits).rjust(7)
        s += str(self.gatecount).rjust(8) + str(self.t_before).rjust(9) + str(self.t_opt).rjust(7) 
        s += str(self.tpar).rjust(8) + str(self.t_after).rjust(8)
        s += "{:.2f}".format(self.time_simpl).rjust(11)
        #s += "{:.2f}".format(self.time_extr).rjust(12)
        s += "       " + self.verified
        #s += str(self.hcount).rjust(8) + str(self.vcount).rjust(8)
        return s

# %% [markdown]
# Next we define a function that loads in a directory of circuit files. Note that the directory we target has up to 3 versions of each circuit:
#
# * circuit_before   - This is the original circuit with any modifications, taken from the [Github page](https://github.com/njross/optimizer) of [[1]](#NRSCM)
# * circuit_after    - This is the circuit produced by the optimization routines of [[1]](#NRSCM).
# * circuit_tpar.qc  - This is the circuit produced by the Tpar algorithm [[2]](#Tpar).
#
# <a id="NRSCM"></a>
# [1] [Nam, Ross, Su, Childs, Maslov - Automated optimization of large quantum circuits with continuous parameters](https://www.nature.com/articles/s41534-018-0072-4)
#
# <a id="Tpar"></a>
# [2] [Amy, Maslov, Mosca - Polynomial-time T-depth Optimization of Clifford+T circuits via Matroid Partitioning](https://arxiv.org/abs/1303.2042)

# %%
def load_circuits(directory):
    d = directory
    beforefiles = []
    afterfiles = []
    tparfiles = []
    for f in os.listdir(d):
        if not os.path.isfile(os.path.join(d,f)): continue
        if f.find('before') != -1:
            beforefiles.append((f,d))
        elif f.find('tpar') != -1:
            tparfiles.append((f,d))
        elif f.find('.qc') != -1 or f.find('.tfc') != -1:
            beforefiles.append((f,d))
        else: afterfiles.append((f,d))
    
    circuits = []
    for f, d in beforefiles:
        if f.find('before') == -1:
            n = os.path.splitext(f)[0]
        else: n = f[:-7]
        for f2,d2 in afterfiles:
            if d!=d2: continue
            if f2.startswith(n):
                c = CircuitComparer(d, f, f2)
                circuits.append(c)
                break
        else:
            c = CircuitComparer(d, f, '')
            circuits.append(c)
        for f2,d2 in tparfiles:
            if d!=d2: continue
            if f2.startswith(n):
                circuits[-1].fname_tpar = os.path.join(d2,f2)
    
    return circuits

dir_fast_circuits = os.path.join('..', 'circuits', 'Fast')
fast_circuits = load_circuits(dir_fast_circuits)

# %% [markdown]
# The directory we target contains a subset of all benchmark circuits, chosen for given quick results. The following cell giving benchmark results of these circuits should therefore only take a few seconds to run. For the benchmarks of slower circuits see [below](#slowbench).
# The columns have the following meaning:
#
# * `Circuit     ` - The name of the circuit
# * `qubits      ` - Amount of qubits in the circuit
# * `G-count     ` - Gate count of original circuit
# * `T-before    ` - Amount of T-gates in original circuit
# * `T-NRSCM     ` - Amount of T-gates in optimised circuit of [[1]](#NRSCM)
# * `T-par       ` - Amount of T-gates in optimised circuit of [[2]](#Tpar)
# * `T-PyZX      ` - Amount of T-gates in optimised circuit made by PyZX
# * `Time-Simp   ` - The time taken for running the simplification routine on the circuit
# * `Time-Extract` - The time taken for extracting the circuit after the simplification
#
# Note that not all circuits were present in the papers [[1]](#NRSCM) and [[2]](#Tpar) in which case the relevant columns are empty.

# %%
print("Circuit".ljust(20), "qubits", "G-count", "T-before", "T-NRSCM", " T-par", " T-PyZX", " Time-Simp","Verified")
for c in fast_circuits:
    print(c.get_output())
# Out:
# Circuit              qubits G-count T-before T-NRSCM  T-par  T-PyZX  Time-Simp Verified
# Adder8                   23     741      266     56       -     266       0.50       Y
# adder_8                  24    1038      399    215     215     399       1.05       Y
# barenco_tof_10           19     514      224    100     100     224       0.29       Y
# barenco_tof_3             5      66       28     16      16      28       0.03       Y
# barenco_tof_4             7     130       56     28      28      56       0.07       Y
# barenco_tof_5             9     194       84     40      40      84       0.10       Y
# csla_mux_3_original      15     190       70     64       -      70       0.09       Y
# csum_mux_9_corrected     30     504      196     84       -     196       0.28       Y
# gf2^10_mult              30    1709      700    410     410     700       1.10       Y
# gf2^4_mult               12     275      112     68      68     112       0.16       Y
# gf2^5_mult               15     429      175    115     111     175       0.30       Y
# gf2^6_mult               18     617      252    150     150     252       0.30       Y
# gf2^7_mult               21     839      343    217     217     343       0.45       Y
# gf2^8_mult               24    1109      448    264     264     448       1.10       Y
# gf2^9_mult               27    1385      567    351     351     567       0.86       Y
# grover_5.qc               9    1057      336      -      52     336       0.78       Y
# ham15-low.qc             17     489      161      -       -     161       0.47       Y
# hwb6.qc                   7     305      105      -       -     105       0.19       -
# mod5_4                    5      73       28     16      16      28       0.03       Y
# mod_mult_55               9     149       49     35      37      49       0.07       Y
# mod_red_21               11     360      119     73      73     119       0.21       Y
# nth_prime6.tfc            9    1261      567      -       -     567       1.58       Y
# qcla_adder_10            36     589      238    162     162     238       0.48       Y
# qcla_com_7               24     531      203     95      95     203       0.39       Y
# qcla_mod_7               26    1016      413    235     249     413       0.87       Y
# QFT16                    16     586      342    144       -     342       0.26       Y
# QFT8                      8     148       84     42       -      84       0.06       Y
# QFTAdd8                  16     476      252    112       -     252       0.26       Y
# qft_4.qc                  5     183       69      -       -      69       0.07       Y
# rc_adder_6               14     238       77     47      63      77       0.15       Y
# tof_10                   19     289      119     71      71     119       0.16       Y
# tof_3                     5      51       21     15      15      21       0.03       Y
# tof_4                     7      85       35     23      23      35       0.06       Y
# tof_5                     9     119       49     31      31      49       0.04       Y
# vbe_adder_3              10     170       70     24      24      70       0.08       Y

# %%
c = zx.Circuit.load("../circuits/Fast/hwb6.qc").to_basic_gates()
g = c.to_graph()
g1 = zx.simplify.teleport_reduce(g.copy())
# Out:
# got a gadget, nodes 172
# after merge, nodes 170
# got a gadget, nodes 168
# after merge, nodes 166
# got a gadget, nodes 164
# after merge, nodes 160
# got a gadget, nodes 160
# after merge, nodes 156
# got a gadget, nodes 156
# after merge, nodes 154
# got a gadget, nodes 152
# after merge, nodes 150

# %%
zx.d3.draw(g)
# Out:
#     <div style="overflow:auto" id="graph-output-1"></div>
#     <script type="text/javascript">
#     require.config({ baseUrl: "../js",
#                      paths: {d3: "d3.v4.min"} });
#     require(['pyzx'], function(pyzx) {
#         pyzx.showGraph('#graph-output-1',
#         JSON.parse('{"nodes": [{"name": "0", "x": 20, "y": 40, "t": 0, "phase": ""}, {"name": "1", "x": 20, "y": 60, "t": 0, "phase": ""}, {"name": "2", "x": 20, "y": 80, "t": 0, "phase": ""}, {"name": "3", "x": 20, "y": 100, "t": 0, "phase": ""}, {"name": "4", "x": 20, "y": 120, "t": 0, "phase": ""}, {"name": "5", "x": 20, "y": 140, "t": 0, "phase": ""}, {"name": "6", "x": 20, "y": 160, "t": 0, "phase": ""}, {"name": "7", "x": 40, "y": 40, "t": 1, "phase": ""}, {"name": "8", "x": 60, "y": 40, "t": 1, "phase": ""}, {"name": "9", "x": 80, "y": 40, "t": 1, "phase": ""}, {"name": "10", "x": 100, "y": 40, "t": 2, "phase": ""}, {"name": "11", "x": 100, "y": 80, "t": 1, "phase": ""}, {"name": "12", "x": 120, "y": 80, "t": 1, "phase": ""}, {"name": "13", "x": 140, "y": 80, "t": 2, "phase": ""}, {"name": "14", "x": 140, "y": 60, "t": 1, "phase": ""}, {"name": "15", "x": 160, "y": 80, "t": 1, "phase": "7\u03c0/4"}, {"name": "16", "x": 180, "y": 80, "t": 2, "phase": ""}, {"name": "17", "x": 180, "y": 40, "t": 1, "phase": ""}, {"name": "18", "x": 200, "y": 80, "t": 1, "phase": "\u03c0/4"}, {"name":
"y": 80, "t": 1, "phase": "\u03c0/4"}, {"name": "52", "x": 500, "y": 60, "t": 1, "phase": "\u03c0/4"}, {"name": "53", "x": 520, "y": 60, "t": 1, "phase": ""}, {"name": "54", "x": 500, "y": 80, "t": 2, "phase": ""}, {"name": "55", "x": 500, "y": 40, "t": 1, "phase": ""}, {"name": "56", "x": 520, "y": 40, "t": 1, "phase": "\u03c0/4"}, {"name": "57", "x": 520, "y": 80, "t": 1, "phase": "7\u03c0/4"}, {"name": "58", "x": 540, "y": 80, "t": 2, "phase": ""}, {"name": "59", "x": 540, "y": 40, "t": 1, "phase": ""}, {"name": "60", "x": 540, "y": 60, "t": 1, "phase": ""}, {"name": "61", "x": 560, "y": 60, "t": 1, "phase": ""}, {"name": "62", "x": 80, "y": 140, "t": 1, "phase": ""}, {"name": "63", "x": 560, "y": 140, "t": 2, "phase": ""}, {"name": "64", "x": 560, "y": 80, "t": 1, "phase": ""}, {"name": "65", "x": 580, "y": 140, "t": 1, "phase": "7\u03c0/4"}, {"name": "66", "x": 600, "y": 140, "t": 2, "phase": ""}, {"name": "67", "x": 600, "y": 40, "t": 1, "phase": ""}, {"name": "68", "x": 620, "y": 140, "t": 1, "pha ...

# %%
c_opt = zx.extract.streaming_extract(g).to_basic_gates()
c_opt = zx.optimize.basic_optimization(c_opt).to_basic_gates()
c_id = c.adjoint()
c_id.add_circuit(c_opt)
g = c_id.to_graph()
zx.simplify.full_reduce(g)
zx.d3.draw(g)
# Out:
# got a gadget, nodes 293
# after merge, nodes 289
# got a gadget, nodes 244
# after merge, nodes 224
# got a gadget, nodes 182
# after merge, nodes 180
# got a gadget, nodes 178
# after merge, nodes 172
# got a gadget, nodes 138
# after merge, nodes 136
# got a gadget, nodes 125
# after merge, nodes 121
# got a gadget, nodes 76
# after merge, nodes 74
#     <div style="overflow:auto" id="graph-output-3"></div>
#     <script type="text/javascript">
#     require.config({ baseUrl: "../js",
#                      paths: {d3: "d3.v4.min"} });
#     require(['pyzx'], function(pyzx) {
#         pyzx.showGraph('#graph-output-3',
#         JSON.parse('{"nodes": [{"name": "0", "x": 20, "y": 40, "t": 0, "phase": ""}, {"name": "1", "x": 20, "y": 60, "t": 0, "phase": ""}, {"name": "2", "x": 20, "y": 80, "t": 0, "phase": ""}, {"name": "3", "x": 20, "y": 100, "t": 0, "phase": ""}, {"name": "4", "x": 20, "y": 120, "t": 0, "phase": ""}, {"name": "5", "x": 20, "y": 140, "t": 0, "phase": ""}, {"name": "6", "x": 20, "y": 160, "t": 0, "phase": ""}, {"name": "64", "x": 480, "y": 40, "t": 1, "phase": "\u03c0"}, {"name": "780", "x": 6840, "y": 40, "t": 0, "phase": ""}, {"name": "781", "x": 6840, "y": 60, "t": 0, "phase": ""}, {"name": "782", "x": 6840, "y": 80, "t": 0, "phase": ""}, {"name": "783", "x": 6840, "y": 100, "t": 0, "phase": ""}, {"name": "784", "x": 6840, "y": 120, "t": 0, "phase": ""}, {"name": "785", "x": 6840, "y": 140, "t": 0, "phase": ""}, {"name": "786", "x": 6840, "y": 160, "t": 0, "phase": ""}], "links": [{"source": "0", "target": "780", "t": 1}, {"source": "1", "target": "781", "t": 1}, {"source": "2", "target": "782", "t": 1}, {"source": "3", "target": "783", "t": 1}, {"source": "4", "target": "64", "t": 2}, {"source": "5", "target": "785", "t": 1}, {"source": "6", "target": "786", "t": 1}, {"source": "64", "target": "784", "t": 2}]}'), 6860, 200, 4.0);
#     });
#     </script>

# %% [markdown]
# <a id="slowbench"></a>
# And now we do the benchmark on the slower circuits. Note that this can take up to half an hour to complete.

# %%
dir_slow_circuits = os.path.join('..', 'circuits', 'Slow')
slow_circuits = load_circuits(dir_slow_circuits)
print("Circuit".ljust(20), "qubits", "G-count", "T-before", "T-NRSCM", " T-par", " T-PyZX", " Time-Simp", " Time-Extract")
for c in slow_circuits:
    print(c.get_output())
# Out:
# Circuit              qubits G-count T-before T-NRSCM  T-par  T-PyZX  Time-Simp  Time-Extract
# Adder16                  47    1437      602    120       -     120       0.58       14.36
# Adder32                  95    3037     1274    248       -     248       1.59      128.39
# Adder64                 191    6237     2618    504       -     504       3.22      510.34
# gf2^16_mult              48    4397     1792   1040    1040    1040       4.65        0.16
# ham15-high.qc            20    6010     2457      -       -    1019       7.39       22.70
# ham15-med.qc             17    1436      574      -       -     212       1.28        1.83
# mod_adder_1024           28    4855     1995   1011    1011    1011       2.31        8.45
# QFT32                    32    1562      918    368       -     368       0.24        0.04
# QFTAdd16                 32    1822     1026    402       -     402       0.46        0.94
# QFTAdd32                 64    4814     2754   1042       -    1042       1.34       35.38

# %%
def load_pf_circuits(directory):
    d = directory
    circuits = []
    for f in os.listdir(d):
        if not os.path.isfile(os.path.join(d,f)): continue
        if f.find('after') == -1: continue
        c = CircuitComparer(d,f,f)
        circuits.append(c)
    return circuits

# %%
dir_pf_circuits = os.path.join('..', 'circuits', 'PF')
pf_circuits = load_pf_circuits(dir_pf_circuits)
print("Circuit".ljust(20), "qubits", "G-count", "T-before", "T-NRSCM", " T-par", " T-PyZX", " Time-Simp", " Time-Extract")
for c in pf_circuits:
    print(c.get_output())
# Out:
# Circuit              qubits G-count T-before T-NRSCM  T-par  T-PyZX  Time-Simp  Time-Extract
# pf1_100_after           100    1500      400    400       -     400      50.88        9.86
# pf1_10_after             10     150       40     40       -      40       0.05        0.02
# pf1_20_after             20     300       80     80       -      80       0.11        0.11
# pf1_30_after             30     450      120    120       -     120       0.66        0.27
# pf1_40_after             40     600      160    160       -     160       0.48        0.44
# pf1_50_after             50     750      200    200       -     200       8.99        5.19
# pf1_60_after             60     900      240    240       -     240       1.61        1.36
# pf1_70_after             70    1050      280    280       -     280       4.58        1.91
# pf1_80_after             80    1200      320    320       -     320      42.77        8.02
# pf1_90_after             90    1350      360    360       -     360      93.12       30.62
# pf2_100_after           100    1900      500    500       -     500      14.32        4.57
# pf2_10_after             10     190       50     50       -      50       0.05        0.01
# pf2_20_after             20     380      100    100       -     100       0.12        0.05
# pf2_30_after             30     570      150    150       -     150       0.29        0.20
# pf2_40_after             40     760      200    200       -     200       0.73        0.38
# pf2_50_after             50     950      250    250       -     250       1.69        2.00
# pf2_60_after             60    1140      300    300       -     300       1.20        2.95
# pf2_70_after             70    1330      350    350       -     350       3.87        4.50
# pf2_80_after             80    1520      400    400       -     400       3.55        6.13
# pf2_90_after             90    1710      450    450       -     450       8.83       11.85
# pf4_10_after             10     950      250    250       -     250       0.56        0.23
# pf4_20_after             20    1900      500    500       -     500       2.89       28.00
# pf4_30_after             30    2850      750    750       -     750       7.75      109.31
# pf4_40_after             40    3800     1000   1000       -    1000      36.34      229.59
# pf4_50_after             50    4750     1250   1250       -    1250      55.72      294.07
# pf4_60_after             60    5700     1500   1500       -    1500      57.57      448.45
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-4facf889a74d> in <module>()
#       3 print("Circuit".ljust(20), "qubits", "G-count", "T-before", "T-NRSCM", " T-par", " T-PyZX", " Time-Simp", " Time-Extract")
#       4 for c in pf_circuits:
# ----> 5     print(c.get_output())
#
# <ipython-input-2-3a7cf8d8fe22> in get_output(self)
#      50     def get_output(self):
#      51         if not self.has_run:
# ---> 52             self.run()
#      53         s = self.name.ljust(20) + str(self.qubits).rjust(7)
#      54         s += str(self.gatecount).rjust(8) + str(self.t_before).rjust(9) + str(self.t_opt).rjust(7)
#
# <ipython-input-2-3a7cf8d8fe22> in run(self)
#      34         g = c.to_graph()
#      35         t = time.time()
# ---> 36         zx.simplify.full_reduce(g)
#      37         self.t_after = zx.tcount(g)
#      38         self.time_simpl = time.time() - t
#
# ~\Documents\Projects\pyzx\pyzx\simplify.py in full_reduce(g, quiet)
#     222     interior_clifford_simp(g, quiet=quiet)
#     223     while True:
# --> 224         pivot_gadget_simp(g,quiet=quiet)
#     225         clifford_simp(g,quiet=quiet)
#     226         i = gadget_simp(g, quiet=quiet)
#
# ~\Documents\Projects\pyzx\pyzx\simplify.py in pivot_gadget_simp(g, matchf, quiet)
#      72
#      73 def pivot_gadget_simp(g, matchf=None, quiet=False):
# ---> 74     return simp(g, 'pivot_gadget_simp', match_pivot_gadget, pivot, matchf=matchf, quiet=quiet)
#      75
#      76 def pivot_boundary_simp(g, matchf=None, quiet=False):
#
# ~\Documents\Projects\pyzx\pyzx\simplify.py in simp(g, name, match, rewrite, matchf, quiet)
#      51             m = match(g, matchf)
#      52         else:
# ---> 53             m = match(g)
#      54         if len(m) > 0:
#      55             i += 1
#
# ~\Documents\Projects\pyzx\pyzx\rules.py in match_pivot_gadget(g, matchf, num)
#     349                     bad_match = True
#     350                     break
# --> 351                 ne = list(g.incident_edges(n))
#     352                 if len(ne) == 1: # v0 or v1 is a phase gadget
#     353                     bad_match = True
#
# ~\Documents\Projects\pyzx\pyzx\graph\graph_s.py in incident_edges(self, vertex)
#     159
#     160         def incident_edges(self, vertex):
# --> 161                 return [(vertex, v1) if v1 > vertex else (v1, vertex) for v1 in self.graph[vertex]]
#     162
#     163         def connected(self,v1,v2):
#
# ~\Documents\Projects\pyzx\pyzx\graph\graph_s.py in <listcomp>(.0)
#     159
#     160         def incident_edges(self, vertex):
# --> 161                 return [(vertex, v1) if v1 > vertex else (v1, vertex) for v1 in self.graph[vertex]]
#     162
#     163         def connected(self,v1,v2):
#
# KeyboardInterrupt:
