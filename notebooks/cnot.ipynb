# %%
import sys
import random
sys.path.append('..')
import pyzx as zx
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
g = zx.generate.cnots(5, 10**5)

# %%
zx.simplify.phase_free_simp(g)
# Out:
# spider_simp
# 32433. 24555. 17735. 11956. 7332. 3841. 1637. 528. 117. 22. 3.
# finished in 12 iterations
# bialg_simp
# 18627. 9716. 6037. 4143. 2883. 2064. 1487. 1164. 867. 676. 515. 395. 299. 232. 191. 135. 104. 80. 59. 53. 44. 27. 26. 25. 16. 15. 12. 7. 5. 2. 3. 3. 2. 2. 1. 1.
# finished in 37 iterations

# %%
zx.drawing.pack_circuit_nf(g,'grg')
zx.draw(g)

# %%
# %time g = zx.cnots(5, 10**6, backend='igraph')
print('built CNOT graph with ' + str(g.num_vertices()) + ' vertices')
# %time zx.phase_free_simp(g)
print(g.num_vertices())
print('final graph has ' + str(g.num_vertices()) + ' vertices')
# Out:
# Wall time: 36 s
# built CNOT graph with 2000020 vertices
# spider_simp
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>()
#
# ~\git\pyzx\pyzx\simplify.py in phase_free_simp(g, quiet)
#      78     '''Performs the following set of simplifications on the graph:
#      79     spider -> bialg'''
# ---> 80     spider_simp(g, quiet=quiet)
#      81     bialg_simp(g, quiet=quiet)
#      82
#
# ~\git\pyzx\pyzx\simplify.py in spider_simp(g, quiet)
#      70
#      71 def spider_simp(g, quiet=False):
# ---> 72     return simp(g, 'spider_simp', match_spider_parallel, spider, quiet=quiet)
#      73
#      74 def id_simp(g, quiet=False):
#
# ~\git\pyzx\pyzx\simplify.py in simp(g, name, match, rewrite, quiet)
#      46         i += 1
#      47         new_matches = False
# ---> 48         m = match(g)
#      49         if len(m) > 0:
#      50             if not quiet: print(len(m), end='')
#
# ~\git\pyzx\pyzx\rules.py in match_spider_parallel(g, num, edgelist)
#     140     while (num == -1 or i < num) and len(candidates) > 0:
#     141         e = candidates.pop()
# --> 142         if g.edge_type(e) != 1: continue
#     143         v0, v1 = g.edge_st(e)
#     144         v0t = types[v0]
#
# KeyboardInterrupt:
# 2000020
# final graph has 2000020 vertices

# %%
zx.drawing.pack_circuit_nf(g, 'grg')
zx.draw(g)

# %%
def f():
    d = {3:4}
    try: del d[3]
    except: pass

# %timeit f()
# Out:
# 247 ns ± 2.25 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
