# %%
import sys
import random
sys.path.append('..')
from pyzx.graph import Graph
from pyzx.examples import *
from pyzx.simplify import *
from pyzx.drawing import *
# Out:
# Available backends: simple, igraph

# %%
g = Graph(backend='igraph')
g.add_vertices(3)

# %%
g.set_vdata(1, 'q', 5)

# %%
g.get_vdata(4, 'q')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-92bf53226603> in <module>()
# ----> 1 g.get_vdata(4, 'q')
#
# ~\git\pyzx\pyzx\graph\graph_ig.py in get_vdata(self, v, key, default)
#      97         def get_vdata(self, v, key, default=0):
#      98                 try:
# ---> 99                         val = self.graph.vs[v][key]
#     100                         if not val: val = default
#     101                 except KeyError:
#
# IndexError: vertex index out of range

# %%
random.seed(99)
g = cnots(5, 300, backend='igraph')
draw(g, layout=dag_layout(g, sort=False))

# %%
d = {0:'a', 3:'b'}
5 in d
# Out:
# False

# %%
phase_free_simp(g)
# Out:
# 105 spider
# 76 spider
# 45 spider
# 29 spider
# 22 spider
# 8 spider
# 3 spider
# 1 spider
# 1 spider
# 1 spider
# finished in 11 iterations
# 60 bialg
# 29 bialg
# 16 bialg
# 14 bialg
# 9 bialg
# 10 bialg
# 4 bialg
# 4 bialg
# 1 bialg
# 1 bialg
# finished in 11 iterations

# %%
draw(g)

# %%
spider_simp(g)
# Out:
# finished in 1 iterations

# %%
draw(g)
