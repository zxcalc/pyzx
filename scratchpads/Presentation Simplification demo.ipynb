# %%
import pyzx as zx

# %%
tikz_code = r"""
\begin{tikzpicture}[tikzfig]
	\begin{pgfonlayer}{nodelayer}
		\node [style=X dot] (0) at (0, 0) {};
		\node [style=X dot] (1) at (0, -1) {};
		\node [style=X dot] (2) at (0, -2) {};
		\node [style=X dot] (3) at (0, -3) {};
		\node [style=Z phase dot] (4) at (2, -2) {$\frac{\pi}{2}$};
		\node [style=X dot] (5) at (3, -3) {};
		\node [style=Z dot] (6) at (3, -2) {};
		\node [style=X dot] (7) at (4.25, -3) {};
		\node [style=Z dot] (8) at (4.25, -1) {};
		\node [style=X dot] (9) at (5.25, -1) {};
		\node [style=Z dot] (10) at (5.25, -3) {};
		\node [style=X dot] (11) at (3.75, -2) {};
		\node [style=Z dot] (12) at (3.75, 0) {};
		\node [style=X dot] (13) at (6.25, 0) {};
		\node [style=Z dot] (14) at (6.25, -1) {};
		\node [style=X dot] (15) at (8.25, -1) {};
		\node [style=Z dot] (16) at (8.25, -2) {};
		\node [style=X dot] (17) at (9.25, -2) {};
		\node [style=Z dot] (18) at (9.25, -3) {};
		\node [style=X dot] (19) at (10.25, -1) {};
		\node [style=Z dot] (20) at (10.25, -3) {};
		\node [style=Z phase dot] (21) at (11.875, -1) {$\frac{\pi}{2}$};
		\node [style=X dot] (22) at (11.25, -2) {};
		\node [style=Z dot] (23) at (11.25, 0) {};
		\node [style=X dot] (24) at (12.75, -1) {};
		\node [style=Z dot] (25) at (12.75, 0) {};
		\node [style=none] (26) at (13.25, 0) {};
		\node [style=none] (27) at (13.25, -1) {};
		\node [style=none] (28) at (13.25, -2) {};
		\node [style=none] (29) at (13.25, -3) {};
		\node [style=hadamard] (30) at (1, -2) {};
		\node [style=hadamard] (31) at (7.25, -1) {};
	\end{pgfonlayer}
	\begin{pgfonlayer}{edgelayer}
		\draw (3) to (5);
		\draw (4) to (6);
		\draw (5) to (6);
		\draw (5) to (7);
		\draw (6) to (11);
		\draw (7) to (8);
		\draw (7) to (10);
		\draw (8) to (9);
		\draw (9) to (10);
		\draw (9) to (14);
		\draw (10) to (18);
		\draw (11) to (12);
		\draw (11) to (16);
		\draw (12) to (13);
		\draw (13) to (14);
		\draw (13) to (23);
		\draw (15) to (16);
		\draw (15) to (19);
		\draw (16) to (17);
		\draw (17) to (18);
		\draw (17) to (22);
		\draw (18) to (20);
		\draw (19) to (20);
		\draw (19) to (21);
		\draw (22) to (23);
		\draw (22) to (28.center);
		\draw (23) to (25);
		\draw (24) to (25);
		\draw (24) to (27.center);
		\draw (0) to (12);
		\draw (25) to (26.center);
		\draw (21) to (24);
		\draw (20) to (29.center);
		\draw (1) to (8);
		\draw (2) to (30);
		\draw (30) to (4);
		\draw (14) to (31);
		\draw (31) to (15);
	\end{pgfonlayer}
\end{tikzpicture}
"""

# %%
g = zx.Graph.from_tikz(tikz_code)
zx.draw(g)
# Out:
# <div style="overflow:auto" id="graph-output-2Mx0JhTs"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
e = zx.editor.edit(g)
# Out:
# <script type="text/javascript">require.config({paths: {d3: "https://cdnjs.cloudflare.com/ajax/libs/d3/5.16.0/d3.min"} });
# 				// PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // When the next line is uncommented, the module is reloaded every time the javascript is imported
# ...

# %%
zx.simplify.full_reduce(g)
g.normalize()
zx.draw(g)
# Out:
# <div style="overflow:auto" id="graph-output-SasWMnbC"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...
